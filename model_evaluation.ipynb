# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('bmi.csv')
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.tail()
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0         1     174      96      4
# 1         1     189      87      2
# 2         0     185     110      4
# 3         0     195     104      3
# 4         1     149      61      3
# ..      ...     ...     ...    ...
# 495       0     150     153      5
# 496       0     184     121      4
# 497       0     141     136      5
# 498       1     150      95      5
# 499       1     173     131      5
#
# [500 rows x 4 columns]

# %%
x=df[['Gender', 'Height', 'Weight']]
y=df['Index']

# %%
print(x.shape) 
print(y.shape)
# Out:
# (500, 3)
# (500,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
lr=LogisticRegression(random_state=42)
dt=DecisionTreeClassifier(random_state=42)
rf=RandomForestClassifier(random_state=42)

# %%
lr.fit(x_train, y_train)
dt.fit(x_train, y_train)
rf.fit(x_train, y_train)
# Out:
# C:\Users\siddhika\ANACONDA\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# RandomForestClassifier(random_state=42)

# %%
y_pred1=lr.predict(x_test)
y_pred2=dt.predict(x_test)
y_pred3=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print('Logistic accuracy', accuracy_score(y_test, y_pred1))
print('decision t accuracy', accuracy_score(y_test, y_pred2))
print('random f accuracy', accuracy_score(y_test, y_pred3))
# Out:
# Logistic accuracy 0.78
# decision t accuracy 0.88
# random f accuracy 0.87

# %% [markdown]
# Decision Tree has best accuracy

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
data=[[0, 1.75, 57]]
dt.predict(data)
# Out:
# C:\Users\siddhika\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
import pickle as pkl

# %%
with open('bmi_model.pkl', "wb") as f:
    pkl.dump(dt, f)

# %%
print(x.columns)
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')
